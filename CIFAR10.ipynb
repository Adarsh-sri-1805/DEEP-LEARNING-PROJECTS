# %% [markdown]
# CIFAR-10

# %%
# Block 1
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# %%
# Block 2
(x_train,y_train),(x_test,y_test) = cifar10.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encoding
y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

# %%
# Block 3
model = Sequential([
    Conv2D(32,(3,3),activation='relu',padding='same',input_shape=(32,32,3)),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(64,(3,3),activation='relu',padding='same'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(128,(3,3),activation='relu',padding='same'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(256,activation='relu'),
    Dropout(0.5),
    Dense(10,activation='softmax')
])

# %%
# Block 4
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train,y_train,
                    epochs=10,
                    validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - accuracy: 0.4891 - loss: 1.4374 - val_accuracy: 0.6178 - val_loss: 1.0962
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.6317 - loss: 1.0499 - val_accuracy: 0.6589 - val_loss: 0.9563
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6927 - loss: 0.8918 - val_accuracy: 0.6553 - val_loss: 0.9658
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7252 - loss: 0.7934 - val_accuracy: 0.6824 - val_loss: 0.9120
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7553 - loss: 0.7070 - val_accuracy: 0.7124 - val_loss: 0.8404
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7783 - loss: 0.6435 - val_accuracy: 0.7292 - val_loss: 0.7901
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7981 - loss: 0.5818 - val_accuracy: 0.7174 - val_loss: 0.8479
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8130 - loss: 0.5351 - val_accuracy: 0.7030 - val_loss: 0.9477
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8300 - loss: 0.4838 - val_accuracy: 0.6967 - val_loss: 0.9642
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8415 - loss: 0.4525 - val_accuracy: 0.7438 - val_loss: 0.8207

# %%
# Block 5
test_loss, test_acc = model.evaluate(x_test,y_test)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7438 - loss: 0.8207
# Test Accuracy: 0.7437999844551086

# %%
class_names = [
'airplane','automobile','bird','cat','deer',
'dog','frog','horse','ship','truck'
]

# %%
index = 0

img = x_test[index]

img_input = np.expand_dims(img, axis=0)

prediction = model.predict(img_input)

predicted_class = np.argmax(prediction)

print("Predicted:", class_names[predicted_class])
print("Actual:", class_names[y_test[index][0]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# Predicted: cat
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2216/1442006167.py in <cell line: 0>()
#      10
#      11 print("Predicted:", class_names[predicted_class])
# ---> 12 print("Actual:", class_names[y_test[index][0]])
#
# TypeError: list indices must be integers or slices, not numpy.float64

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.title(f"Predicted: {class_names[predicted_class]} | Actual: {class_names[y_test[index][0]]}")
plt.axis("off")
plt.show()
